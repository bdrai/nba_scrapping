# %%
import requests


# An api key is emailed to you when you sign up to a plan
# https://api.the-odds-api.com/
API_KEY = '431eee7f792c48b0638e7e812aeba596'

SPORT = 'basketball_nba'#'upcoming' # use the sport_key from the /sports endpoint below, or use 'upcoming' to see the next 8 games across all sports

REGIONS = 'us' # uk | us | eu | au. Multiple can be specified if comma delimited

MARKETS = 'h2h,spreads' # h2h | spreads | totals. Multiple can be specified if comma delimited

ODDS_FORMAT = 'decimal' # decimal | american

DATE_FORMAT = 'iso' # iso | unix



odds_response = requests.get(
    f'https://api.the-odds-api.com/v4/sports/{SPORT}/odds',
    params={
        'api_key': API_KEY,
        'regions': REGIONS,
        'markets': MARKETS,
        'oddsFormat': ODDS_FORMAT,
        'dateFormat': DATE_FORMAT,
    }
)

if odds_response.status_code != 200:
    print(f'Failed to get odds: status_code {odds_response.status_code}, response body {odds_response.text}')

else:
    odds_json = odds_response.json()
    print(odds_json)
    print('Remaining requests', odds_response.headers['x-requests-remaining'])
# Out:
# [{'id': 'e00c3b0837633484d041e85c2b638bbb', 'sport_key': 'basketball_nba', 'sport_title': 'NBA', 'commence_time': '2022-12-09T00:40:00Z', 'home_team': 'Miami Heat', 'away_team': 'Los Angeles Clippers', 'bookmakers': [{'key': 'fanduel', 'title': 'FanDuel', 'last_update': '2022-12-08T13:26:32Z', 'markets': [{'key': 'h2h', 'outcomes': [{'name': 'Los Angeles Clippers', 'price': 2.72}, {'name': 'Miami Heat', 'price': 1.49}]}, {'key': 'spreads', 'outcomes': [{'name': 'Los Angeles Clippers', 'price': 1.91, 'point': 5.0}, {'name': 'Miami Heat', 'price': 1.91, 'point': -5.0}]}]}, {'key': 'wynnbet', 'title': 'WynnBET', 'last_update': '2022-12-08T13:26:25Z', 'markets': [{'key': 'spreads', 'outcomes': [{'name': 'Los Angeles Clippers', 'price': 1.91, 'point': 5.0}, {'name': 'Miami Heat', 'price': 1.91, 'point': -5.0}]}]}, {'key': 'mybookieag', 'title': 'MyBookie.ag', 'last_update': '2022-12-08T13:27:27Z', 'markets': [{'key': 'h2h', 'outcomes': [{'name': 'Los Angeles Clippers', 'price': 2.64}, {'name': 'Miami Heat', 'price': 1.49}]}, {'key': 'spreads', 'outcomes': [{'name': 'Los Angeles Clippers', 'price': 1.91, 'point': 4.5}, {'name': 'Miami Heat', 'price': 1.91, 'point': -4.5}]}]}, {'key': 'betmgm', 'title': 'BetMGM', 'last_update': '2022-12-08T13:24:13Z', 'markets': [{'key': 'h2h', 'outcomes': [{'name': 'Los Angeles Clippers', 'price': 2.65}, {'name': 'Miami Heat', 'price': 1.5}]}, {'key': 'spreads', 'outcomes': [{'name': 'Los Angeles Clippers', 'price': 1.87, 'point': 5.5}, {'name': 'Miami Heat', 'price': 1.95, 'point': -5.5}]}]}, {'key': 'pointsbetus', 'title': 'PointsBet (US)', 'last_update': '2022-12-08T13:26:59Z', 'markets': [{'key': 'h2h', 'outcomes': [{'name': 'Los Angeles Clippers', 'price': 2.75}, {'name': 'Miami Heat', 'price': 1.48}]}, {'key': 'spreads', 'outcomes': [{'name': 'Los Angeles Clippers', 'price': 1.93, 'point': 5.0}, {'name': 'Miami Heat', 'price': 1.93, 'point': -5.0}]}]}, {'key': 'draftkings', 'title': 'DraftKings', 'last_update': '2022-12-08T13:25:35Z', 'markets': [{'key': 'h2h', 'outcomes': [{'name': 'Los Angeles Clippers', 'price': 2.75}, {'name': 'Miami Heat', 'price': 1.49}]}, {'key': 'spreads', 'outcomes': [{'name': 'Los Angeles Clippers', 'price': 1.91, 'point': 5.0}, {'name': 'Miami Heat', 'price': 1.91, 'point': -5.0}]}]}, {'key': 'sugarhouse', 'title': 'SugarHouse', 'last_update': '2022-12-08T13:21:14Z', 'markets': [{'key': 'h2h', 'outcomes': [{'name': 'Los Angeles Clippers', 'price': 2.7}, {'name': 'Miami Heat', 'price': 1.49}]}, {'key': 'spreads', 'outcomes': [{'name': 'Los Angeles Clippers', 'price': 1.89, 'point': 5.0}, {'name': 'Miami Heat', 'price': 1.92, 'point': -5.0}]}]}, {'key': 'unibet_us', 'title': 'Unibet', 'last_update': '2022-12-08T13:26:52Z', 'markets': [{'key': 'h2h', 'outcomes': [{'name': 'Los Angeles Clippers', 'price': 2.7}, {'name': 'Miami Heat', 'price': 1.49}]}, {'key': 'spreads', 'outcomes': [{'name': 'Los Angeles Clippers', 'price': 1.89, 'point': 5.0}, {'name': 'Miami Heat', 'price': 1.92, 'point': -5.0}]}]}, {'key': 'barstool', 'title': 'Barstool Sportsbook', 'last_update': '2022-12-08T13:25:27Z', 'markets': [{'key': 'h2h', 'outcomes': [{'name': 'Los Angeles Clippers', 'price': 2.7}, {'name': 'Miami Heat', 'price': 1.49}]}, {'key': 'spreads', 'outcomes': [{'name': 'Los Angeles Clippers', 'price': 1.89, 'point': 5.0}, {'name': 'Miami Heat', 'price': 1.92, 'point': -5.0}]}]}, {'key': 'twinspires', 'title': 'TwinSpires', 'last_update': '2022-12-08T13:26:17Z', 'markets': [{'key': 'h2h', 'outcomes': [{'name': 'Los Angeles Clippers', 'price': 2.7}, {'name': 'Miami Heat', 'price': 1.49}]}, {'key': 'spreads', 'outcomes': [{'name': 'Los Angeles Clippers', 'price': 1.89, 'point': 5.0}, {'name': 'Miami Heat', 'price': 1.92, 'point': -5.0}]}]}, {'key': 'betrivers', 'title': 'BetRivers', 'last_update': '2022-12-08T13:26:25Z', 'markets': [{'key': 'h2h', 'outcomes': [{'name': 'Los Angeles Clippers', 'price': 2.7}, {'name': 'Miami Heat', 'price': 1.49}]}, {'key': 'spreads', 'outcomes': [{'nam ...
# Remaining requests 488
