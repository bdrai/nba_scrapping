# %%
import requests


# An api key is emailed to you when you sign up to a plan
# https://api.the-odds-api.com/
API_KEY = '431eee7f792c48b0638e7e812aeba596'

SPORT = 'basketball_nba'#'upcoming' # use the sport_key from the /sports endpoint below, or use 'upcoming' to see the next 8 games across all sports

REGIONS = 'us' # uk | us | eu | au. Multiple can be specified if comma delimited

MARKETS = 'h2h,spreads' # h2h | spreads | totals. Multiple can be specified if comma delimited

ODDS_FORMAT = 'decimal' # decimal | american

DATE_FORMAT = 'iso' # iso | unix



odds_response = requests.get(
    f'https://api.the-odds-api.com/v4/sports/{SPORT}/odds',
    params={
        'api_key': API_KEY,
        'regions': REGIONS,
        'markets': MARKETS,
        'oddsFormat': ODDS_FORMAT,
        'dateFormat': DATE_FORMAT,
    }
)

if odds_response.status_code != 200:
    print(f'Failed to get odds: status_code {odds_response.status_code}, response body {odds_response.text}')

else:
    odds_json = odds_response.json()
    print(odds_json)
    print('Remaining requests', odds_response.headers['x-requests-remaining'])
# Out:
# [{'id': 'e848d34845c7d2d339a59de89f221834', 'sport_key': 'basketball_nba', 'sport_title': 'NBA', 'commence_time': '2022-12-06T00:10:00Z', 'home_team': 'Charlotte Hornets', 'away_team': 'Los Angeles Clippers', 'bookmakers': [{'key': 'fanduel', 'title': 'FanDuel', 'last_update': '2022-12-05T16:32:42Z', 'markets': [{'key': 'h2h', 'outcomes': [{'name': 'Charlotte Hornets', 'price': 2.5}, {'name': 'Los Angeles Clippers', 'price': 1.56}]}, {'key': 'spreads', 'outcomes': [{'name': 'Charlotte Hornets', 'price': 1.93, 'point': 4.0}, {'name': 'Los Angeles Clippers', 'price': 1.89, 'point': -4.0}]}]}, {'key': 'wynnbet', 'title': 'WynnBET', 'last_update': '2022-12-05T16:33:08Z', 'markets': [{'key': 'h2h', 'outcomes': [{'name': 'Charlotte Hornets', 'price': 2.48}, {'name': 'Los Angeles Clippers', 'price': 1.57}]}, {'key': 'spreads', 'outcomes': [{'name': 'Charlotte Hornets', 'price': 1.91, 'point': 4.0}, {'name': 'Los Angeles Clippers', 'price': 1.91, 'point': -4.0}]}]}, {'key': 'draftkings', 'title': 'DraftKings', 'last_update': '2022-12-05T16:28:37Z', 'markets': [{'key': 'h2h', 'outcomes': [{'name': 'Charlotte Hornets', 'price': 2.5}, {'name': 'Los Angeles Clippers', 'price': 1.57}]}, {'key': 'spreads', 'outcomes': [{'name': 'Charlotte Hornets', 'price': 1.91, 'point': 4.0}, {'name': 'Los Angeles Clippers', 'price': 1.91, 'point': -4.0}]}]}, {'key': 'pointsbetus', 'title': 'PointsBet (US)', 'last_update': '2022-12-05T16:33:38Z', 'markets': [{'key': 'h2h', 'outcomes': [{'name': 'Charlotte Hornets', 'price': 2.3}, {'name': 'Los Angeles Clippers', 'price': 1.61}]}, {'key': 'spreads', 'outcomes': [{'name': 'Charlotte Hornets', 'price': 1.93, 'point': 4.0}, {'name': 'Los Angeles Clippers', 'price': 1.93, 'point': -4.0}]}]}, {'key': 'betfair', 'title': 'Betfair', 'last_update': '2022-12-05T16:32:33Z', 'markets': [{'key': 'h2h', 'outcomes': [{'name': 'Charlotte Hornets', 'price': 2.52}, {'name': 'Los Angeles Clippers', 'price': 1.61}]}, {'key': 'h2h_lay', 'outcomes': [{'name': 'Charlotte Hornets', 'price': 2.64}, {'name': 'Los Angeles Clippers', 'price': 1.66}]}]}, {'key': 'mybookieag', 'title': 'MyBookie.ag', 'last_update': '2022-12-05T16:32:59Z', 'markets': [{'key': 'h2h', 'outcomes': [{'name': 'Charlotte Hornets', 'price': 2.42}, {'name': 'Los Angeles Clippers', 'price': 1.57}]}, {'key': 'spreads', 'outcomes': [{'name': 'Charlotte Hornets', 'price': 1.91, 'point': 4.0}, {'name': 'Los Angeles Clippers', 'price': 1.91, 'point': -4.0}]}]}, {'key': 'betmgm', 'title': 'BetMGM', 'last_update': '2022-12-05T16:30:53Z', 'markets': [{'key': 'h2h', 'outcomes': [{'name': 'Charlotte Hornets', 'price': 2.35}, {'name': 'Los Angeles Clippers', 'price': 1.62}]}, {'key': 'spreads', 'outcomes': [{'name': 'Charlotte Hornets', 'price': 1.95, 'point': 3.5}, {'name': 'Los Angeles Clippers', 'price': 1.87, 'point': -3.5}]}]}, {'key': 'barstool', 'title': 'Barstool Sportsbook', 'last_update': '2022-12-05T16:32:25Z', 'markets': [{'key': 'h2h', 'outcomes': [{'name': 'Charlotte Hornets', 'price': 2.4}, {'name': 'Los Angeles Clippers', 'price': 1.6}]}, {'key': 'spreads', 'outcomes': [{'name': 'Charlotte Hornets', 'price': 1.91, 'point': 4.0}, {'name': 'Los Angeles Clippers', 'price': 1.91, 'point': -4.0}]}]}, {'key': 'twinspires', 'title': 'TwinSpires', 'last_update': '2022-12-05T16:33:08Z', 'markets': [{'key': 'h2h', 'outcomes': [{'name': 'Charlotte Hornets', 'price': 2.4}, {'name': 'Los Angeles Clippers', 'price': 1.6}]}, {'key': 'spreads', 'outcomes': [{'name': 'Charlotte Hornets', 'price': 1.91, 'point': 4.0}, {'name': 'Los Angeles Clippers', 'price': 1.91, 'point': -4.0}]}]}, {'key': 'betrivers', 'title': 'BetRivers', 'last_update': '2022-12-05T16:32:50Z', 'markets': [{'key': 'h2h', 'outcomes': [{'name': 'Charlotte Hornets', 'price': 2.4}, {'name': 'Los Angeles Clippers', 'price': 1.6}]}, {'key': 'spreads', 'outcomes': [{'name': 'Charlotte Hornets', 'price': 1.91, 'point': 4.0}, {'name': 'Los Angeles Clippers', 'price': 1.91, 'point': -4.0}]}]}, {'key': 'sugarhouse ...
# Remaining requests 494
